# %%
import pandas as pd
import numpy as np

# %%
df_entre = pd.read_csv('../data/films_entree.csv')
df_movie = pd.read_csv('../data/films_api.csv')

# %%
df_entre
# enleve la colonne id
df_entre = df_entre.drop(columns=['id'])

# %%
df_movie
# Out:
#                             titre_fr           realisateur  \
# 0                       Pretty Woman        Garry Marshall
# 1                     Les Affranchis       Martin Scorsese
# 2          Edward aux mains d'argent            Tim Burton
# 3              Le Parrain, 3e partie  Francis Ford Coppola
# 4                              Ghost          Jerry Zucker
# ...                              ...                   ...
# 6240                   Chasse gardée    Frédéric Forestier
# 6241            Avant l'effondrement         Alice Zeniter
# 6242  Le Syndrome des amours passées       Raphaël Balboni
# 6243                         Déserts       Faouzi Bensaïdi
# 6244                 Le consentement         Vanessa Filho
#
#                                                 acteurs  \
# 0     ['Richard Gere', 'Julia Roberts', 'Ralph Bella...
# 1     ['Ray Liotta', 'Robert De Niro', 'Joe Pesci', ...
# 2     ['Johnny Depp', 'Winona Ryder', 'Dianne Wiest'...
# 3     ['Al Pacino', 'Diane Keaton', 'Talia Shire', '...
# 4     ['Patrick Swayze', 'Demi Moore', 'Whoopi Goldb...
# ...                                                 ...
# 6240  ['Hakim Jemili', 'Camille Lou', 'Didier Bourdo...
# 6241  ['Niels Schneider', 'Ariane Labed', 'Souheila ...
# 6242  ['Lucie Debay', 'Lazare Gousseau', 'Nora Hamza...
# 6243  ['Fehd Benchemsi', 'Abdelhadi Talbi', 'Hajar G...
# 6244  ['Kim Higelin', 'Jean-Paul Rouve', 'Sara Girau...
#
#                                                  genres    budget date_sortie  \
# 0                                ['Comédie', 'Romance']  14000000  1990-11-28
# 1                                    ['Drame', 'Crime']  25000000  1990-09-12
# 2                   ['Fantastique', 'Drame', 'Romance']  20000000  1991-04-10
# 3                        ['Crime', 'Drame', 'Thriller']  54000000  2020-12-07
# 4     ['Fantastique', 'Drame', 'Thriller', 'Mystère'...  22000000  1990-11-07
# ...                                                 ...       ...         ...
# 6240                                        ['Comédie']   9827000  2023-12-20
# 6241                                          ['Drame']   2400000  2023-04-19
# 6242              ['Comédie', 'Romance', 'Fantastique']   2000000  2023-10-25
# 6243                                          ['Drame']   1750000  2023-09-20
# 6244                              ['Drame', 'Histoire']   3700000  2023-10-11
#
#                                   compagnies_production
# 0     ['Touchstone Pictures', 'Silver Screen Partner...
# 1                                     ['Winkler Films']
# 2                                  ['20th Century Fox']
# 3                    ['Paramount', 'American Zoetrope']
# 4                                         ['Paramount']
# ...                                                 ...
# 6240  ['Curiosa Films', 'Pictanovo', 'Starman Films'...
# 6241  ['Elzévir Films', 'Après le Déluge', 'France 2...
# 6242             ['Hélicotronc', 'Tripode Productions']
# 6243  ['Barney Production', 'Mont Fleuri Production'...
# 6244  ['Moana Films', 'Windy Production', 'Panache P...
#
# [6245 rows x 7 columns]

# %%
# Convertir les colonnes de date en datetime
df_entre['date'] = pd.to_datetime(df_entre['date'])
df_movie['date_sortie'] = pd.to_datetime(df_movie['date_sortie'])

# Puis compter le nombre de films en 2005
df_entre_2005 = df_entre[df_entre['date'].dt.year == 2014]
print(f"Nombre de films en 2005 dans df_entre : {len(df_entre_2005)}")

df_movie_2005 = df_movie[df_movie['date_sortie'].dt.year == 2014]
print(f"Nombre de films en 2005 dans df_movie : {len(df_movie_2005)}")
# Out:
# Nombre de films en 2005 dans df_entre : 664
# Nombre de films en 2005 dans df_movie : 250

# %%
df_entre[df_entre['title'] == "Star Wars - Le Réveil de la Force"]
# Out:
#                                   title  entries       date
# 4880  Star Wars - Le Réveil de la Force  3801235 2015-12-16

# %%
df_movie[df_movie['titre_fr'] == "Star Wars : Le Réveil de la Force"]
# Out:
#                                titre_fr  realisateur  \
# 4296  Star Wars : Le Réveil de la Force  J.J. Abrams
#
#                                                 acteurs  \
# 4296  ['Harrison Ford', 'Mark Hamill', 'Carrie Fishe...
#
#                                          genres     budget date_sortie  \
# 4296  ['Aventure', 'Action', 'Science-Fiction']  245000000  2015-12-16
#
#                 compagnies_production
# 4296  ['Lucasfilm Ltd.', 'Bad Robot']

# %%
# enleve les : et les espaces
df_entre['title'] = df_entre['title'].str.replace(':', '')
df_movie['titre_fr'] = df_movie['titre_fr'].str.replace(':', '')
# enleve les espaces en trop de tous
df_entre['title'] = df_entre['title'].str.replace(' ', '')
df_movie['titre_fr'] = df_movie['titre_fr'].str.replace(' ', '')
#met tous en minuscule
df_entre['title'] = df_entre['title'].str.lower()
df_movie['titre_fr'] = df_movie['titre_fr'].str.lower()
# enleve les accents titre
df_entre['title'] = df_entre['title'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
df_movie['titre_fr'] = df_movie['titre_fr'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
# enleve l'accent '
df_entre['title'] = df_entre['title'].str.replace("'", '')
df_movie['titre_fr'] = df_movie['titre_fr'].str.replace("'", '')
# enleve virgurle
df_entre['title'] = df_entre['title'].str.replace(",", '')
df_movie['titre_fr'] = df_movie['titre_fr'].str.replace(",", '')
#enleve tiret
df_entre['title'] = df_entre['title'].str.replace("-", '')
df_movie['titre_fr'] = df_movie['titre_fr'].str.replace("-", '')

# %%
#enleve les espaces tous les espaces
df_entre['title'] = df_entre['title'].str.replace(" ", '')
df_movie['titre_fr'] = df_movie['titre_fr'].str.replace(" ", '')

# %%
df_entre[df_entre['title'] == 'starwarslereveildelaforce']
# Out:
#                           title  entries       date
# 4880  starwarslereveildelaforce  3801235 2015-12-16

# %%
df_movie[df_movie['titre_fr'] == 'starwarslereveildelaforce']
# Out:
#                        titre_fr  realisateur  \
# 4296  starwarslereveildelaforce  J.J. Abrams
#
#                                                 acteurs  \
# 4296  ['Harrison Ford', 'Mark Hamill', 'Carrie Fishe...
#
#                                          genres     budget date_sortie  \
# 4296  ['Aventure', 'Action', 'Science-Fiction']  245000000  2015-12-16
#
#                 compagnies_production
# 4296  ['Lucasfilm Ltd.', 'Bad Robot']

# %%
# Renommer les colonnes de df2 pour correspondre à celles de df1
df2 = df_movie.rename(columns={'titre_fr': 'title', 'date_sortie': 'date'})

# %%
# Fusionner les deux dataframes sur le titre et la date
df = pd.merge(df_entre, df2, on=['title', 'date'])

# Calculer le nombre de films qui n'ont pas pu être fusionnés
num_unmerged = len(df_entre) + len(df2) - len(df)

print(f"Nombre de films qui n'ont pas pu être fusionnés : {num_unmerged}")
# Out:
# Nombre de films qui n'ont pas pu être fusionnés : 13399

# %%
df
# Out:
#                       title  entries       date                  realisateur  \
# 0                madagascar   874013 2005-06-22                 Eric Darnell
# 1                     babel   200643 2006-11-15  Alejandro González Iñárritu
# 2     atlantidelempireperdu  1148273 2001-11-28               Gary Trousdale
# 3                      next   262793 2007-04-25                 Lee Tamahori
# 4                 delicieux   130477 2021-09-08                 Éric Besnard
# ...                     ...      ...        ...                          ...
# 2741     lafemmedufossoyeur      842 2022-04-27         Khadar Ayderus Ahmed
# 2742     jumeauxmaispastrop   210444 2022-09-28              Wilfried Méance
# 2743                  piggy      208 2022-11-02               Carlota Pereda
# 2744      sisudeloretdusang    44625 2023-06-21             Jalmari Helander
# 2745      lacourdesmiracles    20495 2022-09-28                   Carine May
#
#                                                 acteurs  \
# 0     ['Ben Stiller', 'Chris Rock', 'David Schwimmer...
# 1     ['Brad Pitt', 'Cate Blanchett', 'Gael García B...
# 2     ['Michael J. Fox', 'Cree Summer', 'James Garne...
# 3     ['Nicolas Cage', 'Julianne Moore', 'Jessica Bi...
# 4     ['Isabelle Carré', 'Grégory Gadebois', 'Benjam...
# ...                                                 ...
# 2741  ['Omar Abdi', 'Yasmin Warsame', 'Kadar Adboul-...
# 2742  ['Ahmed Sylla', 'Bertrand Usclat', 'Pauline Cl...
# 2743  ['Laura Galán', 'Richard Holmes', 'Carmen Mach...
# 2744  ['Jorma Tommila', 'Aksel Hennie', 'Jack Doolan...
# 2745  ['Rachida Brakni', 'Anaïde Rozam', "Sérigne M'...
#
#                                                  genres     budget  \
# 0      ['Familial', 'Animation', 'Aventure', 'Comédie']   75000000
# 1                                             ['Drame']   25000000
# 2     ['Animation', 'Familial', 'Aventure', 'Science...  120000000
# 3             ['Action', 'Science-Fiction', 'Thriller']   70000000
# 4                                 ['Histoire', 'Drame']    5000000
# ...                                                 ...        ...
# 2741                                          ['Drame']    1300000
# 2742                                        ['Comédie']    6200000
# 2743                   ['Horreur', 'Thriller', 'Drame']    2400000
# 2744                               ['Action', 'Guerre']    6200000
# 2745                                        ['Comédie']    3800000
#
#                                   compagnies_production
# 0     ['DreamWorks Pictures', 'Pacific Data Images',...
# 1     ['Babel Productions Inc.', 'Paramount', 'Param...
# 2     ['Walt Disney Pictures', 'Walt Disney Feature ...
# 3     ['Virtual Studios', 'Revolution Studios', 'Sat...
# 4     ['Nord-Ouest Films', 'SND', 'France 3 Cinéma',...
# ...                                                 ...
# 2741  ['Bufo', 'Pyramide Productions', 'Twenty Twent...
# 2742                                      ['Nac Films']
# 2743    ['Morena Films', 'Backup Media', 'Cerdita AIE']
# 2744  ['Subzero Film Entertainment', 'Good Chaos', '...
# 2745  ['France 2', 'France Télévisions', 'Haut et Co...
#
# [2746 rows x 8 columns]

# %%
# enregistre le fichier csv
df.to_csv('../data/films_final_fr.csv', index=False)
